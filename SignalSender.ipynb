# %%
import nidaqmx
import numpy as np
from threading import Thread
import ipywidgets as widgets
import bqplot.pyplot as plt

from bqplot import Axis, Lines, Figure, LinearScale

class SignalSender:
    
    def __init__(self, signal, host='localhost', socket=5557, chan=0):
        self.socket = socket
        self.signal = signal
        self.task =  nidaqmx.Task()
        self.task.ao_channels.add_ao_voltage_chan(
            f'Dev1/ao{chan}'
        )

    def listen(self):
        with self.socket:
            while True:
                #fix to really detect the trigger
                if self.socket.trigger: 
                    self.send_signal()
        
    def send_signal(self):
        with self.task:
            self.task.write(signal)

# %%
def sine_wave(t, freq, amp, **kwargs):
    return amp * np.sin(t * freq * (2*np.pi))

def constant(t, amp, **kwargs):
    return np.ones_like(t) * amp


class SignalGenerator(widgets.VBox):
    
    def __init__(self, samples):
            
        lin_scx = LinearScale(domain=(0, samples))
        lin_scy = LinearScale(domain=(0, 10))
        
        ax_x = Axis(label='X', scale=lin_scx, orientation="horizontal")
        ax_y = Axis(label='Y', scale=lin_scy, orientation="vertical")
        t = np.linspace(samples, 10)
        self.data = np.zeros_like(t)
        self.lines = Lines(
            x=t,
            y=self.data,
            scales={
                "x": lin_scx,
                "y": lin_scy
            },
        )
        self.fig = Figure(
            marks=[self.lines,],
            axes=[ax_x, ax_y],
        )
        
        self.func_selector = widgets.RadioButtons(
            options=[("Sine", sine_wave), ("Constant", constant)], value=sine_wave
        )
        
        self.func_selector.observe(self.update_data)

        self.param_setters = {
            "samples": widgets.BoundedIntText(value=1000, min=1, max=100000, description="Sample number"),
            "freq" : widgets.BoundedFloatText(value=10, min=1, max=100, description="Frequency"),
            "amp": widgets.BoundedFloatText(value=2, min=-10, max=10, description="Amplitude"),
        }
        for widget in self.param_setters.values():
            widget.observe(self.update_data)
        
        self.start_btn = widgets.Button(
            description='Start listening',
            disabled=False,
            button_style='info', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Starts to listen to the socket',
            icon='play'
        )
        self.start_btn.on_click(self.on_start)
        
        
        paramset = widgets.VBox(
            tuple(self.param_setters.values())
        )
        selector = widgets.HBox(
            (paramset, self.func_selector, self.start_btn)
        )
        super().__init__([
            selector,
            self.fig
        ])
        self.update_data(None)
        
        
        
    @property
    def params(self):
        return {key: val.value for key, val in self.param_setters.items()}
        
    def update_data(self, event):
        
        func = self.func_selector.value
        t = np.linspace(0, 10, self.params['samples'])
        self.data = func(t, **self.params)
        self.lines.x = t
        self.lines.y = self.data
        self.fig.marks = [self.lines,]


    def on_start(self, event):
        self.start_btn.button_style = "danger"
        sender = SignalSender(self.data)
        listening = Thread(target=sender.listen)
        listening.run()

# %%
sig_g = SignalGenerator(1000)
sig_g
# Out:
# SignalGenerator(children=(HBox(children=(VBox(children=(BoundedIntText(value=1000, description='Sample number'…
# ---------------------------------------------------------------------------
# DaqNotFoundError                          Traceback (most recent call last)
# <ipython-input-69-8b74429c1e9b> in on_start(self, event)
#      84     def on_start(self, event):
#      85         self.start_btn.button_style = "danger"
# ---> 86         sender = SignalSender(self.data)
#      87         listening = Thread(target=sender.listen)
#      88         listening.run()
#
# <ipython-input-68-804c2b429f4e> in __init__(self, signal, host, socket, chan)
#      12         self.socket = socket
#      13         self.signal = signal
# ---> 14         self.task =  nidaqmx.Task()
#      15         self.task.ao_channels.add_ao_voltage_chan(
#      16             f'Dev1/ao{chan}'
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/task.py in __init__(self, new_task_name)
#      82                 results in an error.
#      83         """
# ---> 84         self._handle = lib_importer.task_handle(0)
#      85
#      86         cfunc = lib_importer.windll.DAQmxCreateTask
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/_lib.py in task_handle(self)
#     176     def task_handle(self):
#     177         if self._task_handle is None:
# --> 178             self._parse_typedefs()
#     179         return self._task_handle
#     180
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/_lib.py in _parse_typedefs(self)
#     239         # If DAQmx 8.8 and lower, TaskHandle is a typedef for uInt32 since
#     240         # DAQmx didn't support 64-bit applications then.
# --> 241         version = system.driver_version
#     242         if version.major_version <= 8 and version.minor_version <= 8:
#     243             self._task_handle = ctypes.c_uint
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/system/system.py in driver_version(self)
#      71                               'update_version'])
#      72
# ---> 73         return DriverVersion(self._major_version, self._minor_version,
#      74                              self._update_version)
#      75
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/system/system.py in _major_version(self)
#     106         val = ctypes.c_uint()
#     107
# --> 108         cfunc = lib_importer.windll.DAQmxGetSysNIDAQMajorVersion
#     109         if cfunc.argtypes is None:
#     110             with cfunc.arglock:
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/_lib.py in windll(self)
#     164     def windll(self):
#     165         if self._windll is None:
# --> 166             self._import_lib()
#     167         return self._windll
#     168
#
# ~/miniconda3/lib/python3.7/site-packages/nidaqmx/_lib.py in _import_lib(self)
#     217             else:
#     218                 raise DaqNotFoundError(
# --> 219                     'Could not find an installation of NI-DAQmx. Please '
#     220                     'ensure that NI-DAQmx is installed on this machine or '
#     221                     'contact National Instruments for support.')
#
# DaqNotFoundError: Could not find an installation of NI-DAQmx. Please ensure that NI-DAQmx is installed on this machine or contact National Instruments for support.
